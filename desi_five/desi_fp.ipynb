# %%
import numpy as np
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline
from desi_fp import desi_five_slice

# %%
fp = desi_five_slice()

# %%
hp.mollview(np.sum(fp * (np.arange(5)+1), axis=1))

# %%
hp.mollview(desi_y4)
